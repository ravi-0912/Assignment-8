# %%
#importing all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from time import sleep
import warnings
warnings.filterwarnings('ignore')
import time
import string

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %% [markdown]
# Q.no 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
#
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
#
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# creating empty lists for scraping data
Rank=[]
Name=[]
Artist=[]
Upload_Date=[]
Views=[]

# %%
#getting the required URL
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/")

# %%
time.sleep(3)

# %%
insert=driver.find_element_by_xpath("//td[@class='mbox-text']/span[@class='plainlinks']/a[@class='external text']/i").click()

# %%
time.sleep(3)

# %%
insert1=driver.find_element_by_xpath("//li[1]/div[@class='mw-search-result-heading']/a").click()

# %%
#scraping the rank
rank=driver.find_elements_by_xpath("//tbody/tr/td[1]")
for i in rank[:30]:
    Rank.append(i.text)
    
time.sleep(5)

#scraping the name
name=driver.find_elements_by_xpath("//tbody/tr/td[2]")
for i in name[:30]:
    Name.append(i.text)
    
time.sleep(5)

#scraping the artist
artist=driver.find_elements_by_xpath("//tbody/tr/td[3]")
for i in artist[:30]:
    Artist.append(i.text)
    
time.sleep(5)

#scraping upload date
upload=driver.find_elements_by_xpath("//tbody/tr/td[5]")
for i in upload[:30]:
    Upload_Date.append(i.text)
    
time.sleep(5)

#scraping views
views=driver.find_elements_by_xpath("//tbody/tr/td[4]")
for i in views[:30]:
    Views.append(i.text)

# %%
#checking the length of each list
print(len(Rank))
print(len(Name))
print(len(Artist))
print(len(Upload_Date))
print(len(Views))
# Out:
# 30
# 30
# 30
# 30
# 30

# %%
#creating a dataframe
df=pd.DataFrame({'Rank':Rank,'Name':Name,'Artist':Artist,'Upload Date':Upload_Date,'Views':Views})

df
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[28]
# 1    2.                                  "Despacito"[30]
# 2    3.                               "Shape of You"[31]
# 3    4.                              "See You Again"[32]
# 4    5.   "Masha and the Bear – Recipe for Disaster"[35]
# 5    6.                       "Johny Johny Yes Papa"[36]
# 6    7.                                "Uptown Funk"[37]
# 7    8.                              "Gangnam Style"[38]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[40]
# 9   10.                                      "Sorry"[41]
# 10  11.                                  "Bath Song"[42]
# 11  12.                                      "Sugar"[43]
# 12  13.                "Phonics Song with Two Words"[44]
# 13  14.                                       "Roar"[45]
# 14  15.                          "Thinking Out Loud"[46]
# ...

# %% [markdown]
# Q2. Scrape the details team India’s international fixtures from bcci.tv.
#
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1
#
# st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
# creating empty lists for scraping data
Match_title=[]
Series=[]
Place=[]
Date=[]
Month=[]
Time=[]

# %%
#getting the required Url
driver.get("https://www.bcci.tv/")

# %%
insert = driver.find_element_by_xpath("//li[1]//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']")
insert.click()

# %%
insert1 = driver.find_element_by_xpath("//li[1]/div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div[1]/ul[1]/li[1]/a[@href='/international/fixtures']")
insert1.click()

# %%
#scraping match title
match = driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/strong")
for i in match:
    Match_title.append(i.text)
    

#scraping series
series = driver.find_elements_by_xpath("//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in series:
    Series.append(i.text)
    

#scraping place
place = driver.find_elements_by_xpath("//p[@class='fixture__additional-info']/span")
for i in place:
    Place.append(i.text)
    

#scraping date
date = driver.find_elements_by_xpath("//div[@class='fixture__full-date']/span")
for i in date:
    Date.append(i.text)
    

#scraping month
month = driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[1]")
for i in month:
    Month.append(i.text)
    

#scraping time
time = driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[2]")
for i in time:
    Time.append(i.text)

# %%
#checking the length of each list
print(len(Match_title))
print(len(Series))
print(len(Place))
print(len(Date))
print(len(Month))
print(len(Time))
# Out:
# 10
# 10
# 10
# 10
# 10
# 10

# %%
#creating a dataframe
df1=pd.DataFrame({'Match Title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Month':Month,'Time':Time})

df1
# Out:
#   Match Title                     Series                                Place  \
# 0    3rd T20I  AUSTRALIA V INDIA 2020/21        Sydney Cricket Ground, Sydney
# 1    1st Test  AUSTRALIA V INDIA 2020/21              Adelaide Oval, Adelaide
# 2    2nd Test  AUSTRALIA V INDIA 2020/21  Melbourne Cricket Ground, Melbourne
# 3    3rd Test  AUSTRALIA V INDIA 2020/21        Sydney Cricket Ground, Sydney
# 4    4th Test  AUSTRALIA V INDIA 2020/21    Brisbane Cricket Ground, Brisbane
# 5    1st Test       ENGLAND V INDIA 2021             Trent Bridge, Nottingham
# 6    2nd Test       ENGLAND V INDIA 2021                       Lord's, London
# 7    3rd Test       ENGLAND V INDIA 2021                    Headingley, Leeds
# 8    4th Test       ENGLAND V INDIA 2021                     The Oval, London
# 9    5th Test       ENGLAND V INDIA 2021             Old Trafford, Manchester
#
#   Date      Month       Time
# 0   08   DECEMBER  13:40 IST
# 1   17   DECEMBER  09:30 IST
# ...

# %% [markdown]
# Q3.Scrape the details of selenium exception from guru99.com.
#
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
# creating empty lists for scraping data
Name=[]
Description=[]

# %%
#getting the required Url
driver.get("https://www.guru99.com/")

# %%
time.sleep(3)

# %%
insert4 = driver.find_element_by_xpath("//ul[@class='menu']/li[3]/a[@title='Selenium']").click()

# %%
insert5 = driver.find_element_by_xpath("//td[@class='responsivetable']/a[@title='Selenium Exception Handling (Common Exceptions List)']/strong")
insert5.click()

# %%
insert6=driver.find_element_by_xpath("//button[@class='CloseButton__ButtonElement-sc-79mh24-0 gVNUOF aurora-CloseButton aurora-close aurora-ClosePosition--top-right']").click()

# %%
#scraping name
name= driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
for i in name:
    Name.append(i.text)

# %%
Name
# Out:
# ['Exception name',
#  'ElementNotVisibleException',
#  'ElementNotSelectableException',
#  'NoSuchElementException',
#  'NoSuchFrameException',
#  'NoAlertPresentException',
#  'NoSuchWindowException',
#  'StaleElementReferenceException',
#  'SessionNotFoundException',
#  'TimeoutException',
#  'WebDriverException',
#  'ConnectionClosedException',
#  'ElementClickInterceptedException',
#  'ElementNotInteractableException',
#  'ErrorInResponseException',
#  'ErrorHandler.UnknownServerException',
#  'ImeActivationFailedException',
#  'ImeNotAvailableException',
#  'InsecureCertificateException',
#  'InvalidArgumentException',
#  'InvalidCookieDomainException',
#  'InvalidCoordinatesException',
#  'InvalidElementStateExceptio',
#  'InvalidSessionIdException',
#  'InvalidSwitchToTargetException',
#  'JavascriptException',
#  'JsonException',
#  'NoSuchAttributeException',
#  'MoveTargetOutOfBoundsException',
#  'NoSuchContextException',
#  'NoSuchCookieException',
# ...

# %%
#creating a dataframe
Name1 = pd.DataFrame(Name)
Name2= Name1.rename(columns = { 0:' Name'})
Name2
# Out:
#                                    Name
# 0                        Exception name
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# ...

# %%
Name3 =Name2.iloc[1:42]
Name3
# Out:
#                                    Name
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# 22          InvalidElementStateExceptio
# ...

# %%
#scraping description
description = driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
for i in description:
    Description.append(i.text)

# %%
Description
# Out:
# ['Description',
#  'This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'This Exception occurs if an element could not be found.',
#  'This Exception occurs if the frame target to be switched to does not exist.',
#  'This Exception occurs when you switch to no presented alert.',
#  'This Exception occurs if the window target to be switch does not exist.',
#  'This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'The WebDriver is acting after you quit the browser.',
#  "Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn't found in the specified time.",
#  'This Exception takes place when the WebDriver is acting right after you close the browser.',
# ...

# %%
#creating a dataframe
Description1 = pd.DataFrame(Description)
Description2= Description1.rename(columns = { 0:'Description'})
Description2
# Out:
#                                           Description
# 0                                         Description
# 1   This type of Selenium exception occurs when an...
# 2   This Selenium exception occurs when an element...
# 3   This Exception occurs if an element could not ...
# 4   This Exception occurs if the frame target to b...
# 5   This Exception occurs when you switch to no pr...
# 6   This Exception occurs if the window target to ...
# 7   This Selenium exception occurs happens when th...
# 8   The WebDriver is acting after you quit the bro...
# 9   Thrown when there is not enough time for a com...
# 10  This Exception takes place when the WebDriver ...
# 11  This type of Exception takes place when there ...
# 12  The command may not be completed as the elemen...
# 13  This Selenium exception is thrown when any ele...
# 14  This happens while interacting with the Firefo...
# 15  Exception is used as a placeholder in case if ...
# ...

# %%
Description3 = Description2.iloc[1:42]
Description3
# Out:
#                                           Description
# 1   This type of Selenium exception occurs when an...
# 2   This Selenium exception occurs when an element...
# 3   This Exception occurs if an element could not ...
# 4   This Exception occurs if the frame target to b...
# 5   This Exception occurs when you switch to no pr...
# 6   This Exception occurs if the window target to ...
# 7   This Selenium exception occurs happens when th...
# 8   The WebDriver is acting after you quit the bro...
# 9   Thrown when there is not enough time for a com...
# 10  This Exception takes place when the WebDriver ...
# 11  This type of Exception takes place when there ...
# 12  The command may not be completed as the elemen...
# 13  This Selenium exception is thrown when any ele...
# 14  This happens while interacting with the Firefo...
# 15  Exception is used as a placeholder in case if ...
# 16  This expectation will occur when IME engine ac...
# ...

# %%
Selenium_Exception = pd.concat([Name3,Description3 ] , axis=1)
Selenium_Exception
# Out:
#                                    Name  \
# 1            ElementNotVisibleException
# 2         ElementNotSelectableException
# 3                NoSuchElementException
# 4                  NoSuchFrameException
# 5               NoAlertPresentException
# 6                 NoSuchWindowException
# 7        StaleElementReferenceException
# 8              SessionNotFoundException
# 9                      TimeoutException
# 10                   WebDriverException
# 11            ConnectionClosedException
# 12     ElementClickInterceptedException
# 13      ElementNotInteractableException
# 14             ErrorInResponseException
# 15  ErrorHandler.UnknownServerException
# 16         ImeActivationFailedException
# 17             ImeNotAvailableException
# 18         InsecureCertificateException
# 19             InvalidArgumentException
# 20         InvalidCookieDomainException
# 21          InvalidCoordinatesException
# 22          InvalidElementStateExceptio
# ...

# %% [markdown]
# Q4.Scrape the details of State-wise GDP of India from statisticstime.com.
#
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
# creating empty lists for scraping data
Rank=[]
State=[]
GSDP_18=[]
GSDP_17=[]
Share=[]
GDP_Billion=[]

# %%
#getting the required Url
driver.get("http://statisticstimes.com/")

# %%
time.sleep(5)

# %%
insert = driver.find_element_by_xpath("//div/div/div[2]/button")
insert.click()

# %%
time.sleep(5)

# %%
insert1=driver.find_element_by_xpath("//div[@class='navbar']/div[2]/div/a[2]")
insert1.click()

# %%
time.sleep(5)

# %%
insert2 = driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']/li/a")
insert2.click()

# %%
time.sleep(3)

# %%
#scraping rank
rank=driver.find_elements_by_xpath("//tr/td[@class='data1']")
for i in rank[:33]:
    Rank.append(i.text)

time.sleep(3)

#scraping state
state=driver.find_elements_by_xpath("//tr/td[@class='name']")
for j in state[:33]:
    State.append(j.text)
    
time.sleep(3)

#scraping GSDP (18-19)
gsdp18=driver.find_elements_by_xpath("//tr/td[3][@class='data']")
for j in gsdp18[:33]:
    GSDP_18.append(j.text)
    
time.sleep(3)

#scraping GSDP (17-18)
gsdp17=driver.find_elements_by_xpath("//tr/td[@class='data sorting_1']")
for j in gsdp17[:33]:
    GSDP_17.append(j.text)
    
time.sleep(3)

#scraping share
share=driver.find_elements_by_xpath("//tr/td[5][@class='data']")
for j in share[:33]:
    Share.append(j.text)
    
time.sleep(3)

#scraping GDP in billion$
billion=driver.find_elements_by_xpath("//tr/td[6][@class='data']")
for j in billion[:33]:
    GDP_Billion.append(j.text)

# %%
#checking the length of each list
print(len(Rank))
print(len(State))
print(len(GSDP_18))
print(len(GSDP_17))
print(len(GDP_Billion))
# Out:
# 33
# 33
# 33
# 33
# 33

# %%
#creating a dataframe
df4=pd.DataFrame({'Rank':Rank,'State':State,'GSDP18-19':GSDP_18,'GSDP17-18':GSDP_17,'Share 2017':Share,'GDP $ billion':GDP_Billion})

df4
# Out:
#    Rank                      State  GSDP18-19  GSDP17-18 Share 2017  \
# 0     1                Maharashtra          -  2,411,600     14.11%
# 1     2                 Tamil Nadu  1,664,159  1,461,841      8.55%
# 2     3              Uttar Pradesh  1,542,432  1,376,324      8.05%
# 3     4                  Karnataka  1,535,224  1,350,257      7.90%
# 4     5                    Gujarat          -  1,314,680      7.69%
# 5     6                West Bengal  1,177,586    999,585      5.85%
# 6     7                  Rajasthan    929,124    835,558      4.89%
# 7     8             Andhra Pradesh    933,402    809,547      4.74%
# 8     9                  Telangana    865,688    753,811      4.41%
# 9    10             Madhya Pradesh    809,327    728,242      4.26%
# 10   11                     Kerala          -    700,532      4.10%
# 11   12                      Delhi    779,652    690,098      4.04%
# 12   13                    Haryana    707,126    626,054      3.66%
# ...

# %% [markdown]
# Q6.Scrape the details of top 100 songs on billiboard.com.
#
# Url = https://www.billiboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
#getting the required Url
driver.get("https://www.billboard.com/")

# %%
# creating empty lists for scraping data
song_name = []
artist_name  = []
last_week_rank  = []
peak_rank  = []
weeks_on_board = []

# %%
time.sleep(5)

# %%
insert = driver.find_element_by_xpath("//header[@class='header header--desktop padding-x--sm flex--space-between-center bg--dark']/div[@class='header__main-menu__wrapper flex--grow']/ul/li[1]/a").click()

# %%
time.sleep(5)

# %%
insert1=driver.find_element_by_id("pmc_toupp_notice_close_btn").click()

# %%
insert2 = driver.find_element_by_xpath("//div[@class='charts-landing__info charts-landing__info--hot-100']/div")
insert2.click()

# %%
time.sleep(4)

# %%
#scraping name
name = driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[1]")
for i in name:
    song_name.append(i.text)
    
time.sleep(3)

#scraping artist name
artist = driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[2]")
for i in artist:
    artist_name.append(i.text)
    
time.sleep(3)

#scraping last week rank
week = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in week:
    last_week_rank.append(i.text)
    
time.sleep(3)

#scraping peak rank
peak = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in peak:
    peak_rank.append(i.text)
    
time.sleep(3)

#scraping weeks on board
week = driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in week:
    weeks_on_board.append(i.text)

# %%
#checking the length of each list
print(len(song_name))
print(len(artist_name))
print(len(last_week_rank))
print(len(peak_rank))
print(len(weeks_on_board))
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
#creating a dataframe
df5=pd.DataFrame({'Song Name':song_name,'Artist Name':artist_name,'Last Week Rank':last_week_rank,'Peak Rank':peak_rank,'Weeks On Board':weeks_on_board})

df5
# Out:
#        Song Name                           Artist Name Last Week Rank  \
# 0   Life Goes On                                   BTS              -
# 1           Mood          24kGoldn Featuring iann dior              1
# 2       Dynamite                                   BTS             14
# 3      Positions                         Ariana Grande              3
# 4         I Hope  Gabby Barrett Featuring Charlie Puth              4
# ..           ...                                   ...            ...
# 95       Popstar             DJ Khaled Featuring Drake             83
# 96       Bichota                               Karol G              -
# 97    Happy Does                         Kenny Chesney             90
# 98   Cover Me Up                         Morgan Wallen              -
# 99       So Done                         The Kid LAROI             75
#
#    Peak Rank Weeks On Board
# 0          1              1
# 1          1             16
# 2          1             14
# ...

# %% [markdown]
# Q7.Scrape the details of Data science recruiters from naukri.com.
#
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
# creating empty lists for scraping data
name  = []
designation  = []
company  = []
skills   = []
location = []

# %%
#closing unnecessary pop windows by using window handler and applying filter in the Url
time.sleep(5)
driver.switch_to_window(driver.window_handles[1])
driver.close()
time.sleep(5)
driver.switch_to_window(driver.window_handles[1])
driver.close()
driver.switch_to_window(driver.window_handles[0])
time.sleep(10)
Task1 = driver.find_element_by_xpath("//div[@class='privacyPolicy']/div//button")
Task1.click()
time.sleep(10)
Task2 = driver.find_element_by_xpath("//div[@class='userPrompt animate']//span[1]")
Task2.click()
time.sleep(10)
Task3 = driver.find_element_by_xpath("//ul[@class='midSec menu']/li[2]/a/div")
Task3.click()
time.sleep(5)
driver.switch_to_window(driver.window_handles[1])
time.sleep(5)
Task4 = driver.find_element_by_xpath("//div[@class='sWrap lftBrd']/div[2]/input")
Task4.send_keys('Data Science')
time.sleep(10)
Task5 = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
Task5.click()
time.sleep(5)

# %%
#scraping name
Name = driver.find_elements_by_xpath("//p[@class='highlightable']//span[@class='fl ellipsis']")
for i in Name:
    name.append(i.text)
    
time.sleep(3)  

#scraping designation
Designation = driver.find_elements_by_xpath("//p[@class='highlightable']//span[@class='ellipsis clr']")
for i in Designation:
    designation.append(i.text)
    
time.sleep(3)  

#scraping company name
Company = driver.find_elements_by_xpath("//p[@class='highlightable']/a[2]")
for i in Company:
    company.append(i.text)

time.sleep(3)  

#scraping skills required
Skills= driver.find_elements_by_xpath("//div[@class='recInfo']//div[@class='hireSec highlightable']")
for i in Skills:
    skills.append(i.text)

# %%
## scraping location, for scraping location we have to go in each of the location separately
urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//div[@class='vcard']/p/a[1]")]#getting the url
for url in urls[0:50]:
    time.sleep(5)
    try:            #exception handling for nosuchelementexception
        
        driver.get(url)
        Location=driver.find_element_by_xpath("//div[@class='rFrame fl infoWrapper']/div[5]/a").text
        
        location.append(Location)#appending location in location list
    except NoSuchElementException :
        location.append(" ")#appending no location if no such location is there

# %%
#checking the length of each list
print(len(name))
print(len(designation))
print(len(company))
print(len(skills))
print(len(location))
# Out:
# 50
# 50
# 50
# 50
# 50

# %%
#creating a dataframe
df7=pd.DataFrame({'Name':name,'Designation':designation,'Company':company,'Skills':skills,'Location':location})

df7
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                    Talent Acquisition Executive
# 3                                    Anik Agrawal
# 4                        MARSIAN Technologies LLP
# 5                                    subhas patel
# 6                                  Jitendra Singh
# 7    Abhishek - Only Analytics Hiring - India and
# 8   Institute for Financial Management and Resear
# 9                                     Balu Ramesh
# 10                                  Asif Lucknowi
# 11                                InstaFinancials
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                                  Manisha Yadav
# 16                                   Kapil Devang
# 17                                    Riya Rajesh
# ...

# %% [markdown]
# Q8.Scrape the details of Highest selling novels.
#
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
#getting the required url
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
# creating empty lists for scraping data
book_name = []
author_name  = []
volumes_sold  = []
publisher  = []
genre  = []

# %%
#scraping book name
book = driver.find_elements_by_xpath("//tbody/tr/td[2]")
for i in book:
    book_name.append(i.text)

#scraping author name
author = driver.find_elements_by_xpath("//tbody/tr/td[3]")
for i in author:
    author_name.append(i.text)

#scraping volumes sold
volume = driver.find_elements_by_xpath("//tbody/tr/td[4]")
for i in volume:
    volumes_sold.append(i.text)

#scraping publisher 
publish = driver.find_elements_by_xpath("//tbody/tr/td[5]")
for i in publish:
    publisher.append(i.text)

#scraping genre
Genre = driver.find_elements_by_xpath("//tbody/tr/td[6]")
for i in Genre:
    genre.append(i.text)

# %%
#checking the length of each list
print(len(book_name))
print(len(author_name))
print(len(volumes_sold))
print(len(publisher))
print(len(genre))
# Out:
# 100
# 100
# 100
# 100
# 100

# %%
#creating a dataframe
df8=pd.DataFrame({'Book Name':book_name,'AUthor Name':author_name,'Volumes Sold':volumes_sold,'Publisher':publisher,'Genre':genre})

df8
# Out:
#                                             Book Name       AUthor Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# Q9. Scrape the details most watched tv series of all time from imdb.com.
#
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
#getting the required url
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
# creating empty lists for scraping data
name=[]
year=[]
genre=[]
runtime=[]
ratings=[]
votes=[]

# %%
#scraping name
Name=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
for i in Name:
    name.append(i.text)
    
#scraping year
Year=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in Year:
    year.append(i.text)

#scraping genre
Genre=driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[5]")
for i in Genre:
    genre.append(i.text)

#scraping runtime
rt=driver.find_elements_by_xpath("//p[@class='text-muted text-small']/span[3]")
for i in rt:
    runtime.append(i.text)

#scraping ratings
Rating=driver.find_elements_by_xpath("//div[@class='ipl-rating-widget']/div/span[2]")
for i in Rating:
    ratings.append(i.text)

#scraping votes
Votes=driver.find_elements_by_xpath("//p[4][@class='text-muted text-small']/span[2]")
for i in Votes:
    votes.append(i.text)

# %%
#checking the length of each list
print(len(name))
print(len(year))
print(len(genre))
print(len(runtime))
print(len(ratings))
print(len(votes))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100

# %%
#creating a dataframe
df9=pd.DataFrame({'Name':name,'Year':year,'Genre':genre,'Run Time':runtime,'Ratings':ratings,'Votes':votes})

df9
# Out:
#                               Name         Year                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead     (2010– )   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series     (2015– )      Crime, Drama, Horror
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.3  1,735,249
# ...

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories.
#
#  Url = https://archive.ics.uci.edu/
#
#  You have to find the following details:
#
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
#intialising driver
driver=webdriver.Chrome(r"C:\Users\verma\Desktop\Selenium\chromedriver.exe")

# %%
#getting the required url
driver.get("https://archive.ics.uci.edu/")

# %%
# creating empty lists for scraping data
dataset_name = []
data_type  = []
task  = []
attribute_type  = []
no_of_instances  = []
no_of_attribute  = []
year = []

# %%
insert1 = driver.find_element_by_xpath("//b/a[@href='datasets.php']")
insert1.click()

# %%
urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//p[@class='normal']/b/a")]
for url in urls[:559]:
    time.sleep(5)
    try:         #exception handling for nosuchelementexception
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//span[@class='heading']/b").text
        des=raw_description.replace("Data Set","")
        dataset_name.append(des)   #appending dataset name in dataset name list
    except NoSuchElementException :
        dataset_name.append(" ") #appending the no dataset name if no name is given
        
    try:    #exception handling for nosuchelementexception
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//tbody/tr[1]/td[2]/p[@class='normal']").text      
        data_type.append(raw_description)#appending datatype in datatype list
    except NoSuchElementException :
        data_type.append(" ")#appending no dataset type if no type is provided

    try:    #exception handling for nosuchelementexception
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//tbody/tr[3]/td[2]/p[@class='normal']").text      
        task.append(raw_description)#appending task in task list
    except NoSuchElementException :
        task.append(" ")#appending no task if no task is given

    try:   #exception handling for nosuchelementexception
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//tbody/tr[2]/td[2]/p[@class='normal']").text      
        attribute_type.append(raw_description)#appending attribute type in attribute type list
    except NoSuchElementException :
        attribute_type.append(" ")#appending no attribute type if no type is given
    try:   #exception handling for nosuchelementexception
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//tbody/tr[1]/td[4]/p[@class='normal']").text      
        no_of_instances.append(raw_description)#appending no of instances
    except NoSuchElementException :
        no_of_instances.append(" ")#appending no No of instanced is no instances is given

    try:   #exception handling for nosuchelementexception
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//tbody/tr[2]/td[4]/p[@class='normal']").text      
        no_of_attribute.append(raw_description)#appending  no of attribute
    except NoSuchElementException :
        no_of_attribute.append(" ")#appending no No of attribute if data is not give

    try:   #exception handling for nosuchelementexception
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//tbody/tr[2]/td[6]/p[@class='normal']").text 
        des=raw_description[0:4]
        year.append(raw_description)#appending year
    except NoSuchElementException :
        year.append(" ")#appending no year if no year is given

# %%
#creating a dataframe
df10=pd.DataFrame({"Dataset Name":dataset_name,"Data Type":data_type,"Task":task,"Attribute Type":attribute_type,"No of instances":no_of_instances,
                "No of attribute":no_of_attribute , "Year" : year})

df10
# Out:
#                                           Dataset Name     Data Type  \
# 0                                             Abalone   Multivariate
# 1                                               Adult   Multivariate
# 2                                           Annealing   Multivariate
# 3                        Anonymous Microsoft Web Data            N/A
# 4                                          Arrhythmia   Multivariate
# ..                                                 ...           ...
# 554         IIWA14-R820-Gazebo-Dataset-10Trajectories            N/A
# 555                    Guitar Chords finger positions           Text
# 556              Russian Corpus of Biographical Texts           Text
# 557                                       Codon usage   Multivariate
# 558  Intelligent Media Accelerometer and Gyroscope ...   Time-Series
#
#                            Task              Attribute Type No of instances  \
# ...
